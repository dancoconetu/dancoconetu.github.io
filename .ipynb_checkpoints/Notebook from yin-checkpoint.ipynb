# %%
import pandas as pd
df = pd.read_csv("nypd.csv")
# Out:
# /Users/Enchanter/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inattetion =  df.loc[df['CONTRIBUTING FACTOR VEHICLE 1'] == "Driver Inattention/Distraction"]
timespan = ( pd.to_datetime(inattetion['DATE'])  >= '2016-1-1') & ( pd.to_datetime(inattetion['DATE'])  < '2017-1-1')
inattention2016 = inattetion.loc[timespan]
days = pd.date_range(start=pd.datetime(2016, 1, 1), periods=366, freq='D')

x=[]
y=[]

    
for i in range(0,366):
    for j in range(8,20):
        x.append(j)

for i in range(0,366):
    k = '{:%m/%d/%Y}'.format(days[i])
    
    tmp  = inattention2016.loc[inattention2016['DATE']==k]
    for j in range(8,20):
        if j<9:
            hours  = (tmp['TIME']>= '0%i:00'%j) & (tmp['TIME']<='0%i:00'%(j+1))
        else:
            if j==9:
                hours  = (tmp['TIME']>= '0%i:00'%j) & (tmp['TIME']<='%i:00'%(j+1))
            else:
                hours  = (tmp['TIME']>= '%i:00'%j) & (tmp['TIME']<='%i:00'%(j+1))
        tmpH = tmp.loc[hours]
        y.append(len(tmpH))

# %%
data = []
for i in range(0,12):
    data.append([])

idx = 0 
for j in y:
    data[idx].append(j)
    idx = (idx+1) % 12

# %%
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
line = plt.figure()
xarray = np.asarray(x)
xarray = xarray.reshape(4392,1)
lin = linear_model.LinearRegression()
lin.fit(xarray,y)
alpha = lin.intercept_
beta = lin.coef_[0]

for i in range(0,12):
    a = [i+8 for j in range(0,366)]
    b = data[i]
    plt.scatter(a, b, color="black")

plt.plot(xarray, lin.predict(xarray), color='red'
         ,linewidth=3)
plt.show()

# %%
timespan = ( pd.to_datetime(inattetion['DATE'])  >= '2016-1-1') & ( pd.to_datetime(inattetion['DATE'])  < '2017-1-1')
inattention2016 = inattetion.loc[timespan]
mean = []
for i in range(8,20):
    if i<9:
        hours  = (inattention2016['TIME']>= '0%i:00'%i) & (inattention2016['TIME']<='0%i:00'%(i+1))
    else:
        if i==9:
            hours  = (inattention2016['TIME']>= '0%i:00'%i) & (inattention2016['TIME']<='%i:00'%(i+1))
        else:
            hours  = (inattention2016['TIME']>= '%i:00'%i) & (inattention2016['TIME']<='%i:00'%(i+1))
    everyH = inattention2016.loc[hours]
    mean.append(len(everyH)/366)
print "Average inattention in each hours : ", mean
# Out:
# Average inattention in each hours :  [0.0, 3.079234972677596, 4.423497267759563, 4.778688524590164, 5.23224043715847, 5.366120218579235, 6.251366120218579, 5.8224043715847, 6.96448087431694, 6.554644808743169, 5.797814207650274, 5.959016393442623]

# %%
xi2 = []
for i in range(0,366):
    k = '{:%m/%d/%Y}'.format(days[i])
    
    tmpDays  = inattention2016.loc[inattention2016['DATE']==k]
    for j in range(8,20):
        if j<9:
            hours  = (tmpDays['TIME']>= '0%i:00'%j) & (tmpDays['TIME']<='0%i:00'%(j+1))
        else:
            if j==9:
                hours  = (tmpDays['TIME']>= '0%i:00'%j) & (tmpDays['TIME']<='%i:00'%(j+1))
            else:
                hours  = (tmpDays['TIME']>= '%i:00'%j) & (tmpDays['TIME']<='%i:00'%(j+1))
        tmpHours = tmpDays.loc[hours]
        xi2.append(len(tmpHours) - mean[j-8])

# %%
xi1 = np.array(x).reshape(4392,1)
xi2 = np.array(xi2).reshape(4392,1)
tmp = np.column_stack((xi1,xi2))
regrMultiple = linear_model.LinearRegression()
regrMultiple.fit(tmp,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# %matplotlib inline
line = plt.figure()
for i in range(0,12):
    a = [i+8 for j in range(0,366)]
    b = data[i]
    plt.scatter(a, b, color="black")
plt.plot(xarray, regrMultiple.predict(tmp), color='red',
        linewidth=3)
plt.show()

# %%
car =  df.loc[df['VEHICLE TYPE CODE 1'] == "PASSENGER VEHICLE"]
car.dropna(subset=['LATITUDE'], inplace=True)
car.dropna(subset=['LONGITUDE'], inplace=True)
car
# Out:
# /Users/Enchanter/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/Enchanter/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 2        05/02/2017   0:00       BROOKLYN    11212  40.660050 -73.917430
# 3        05/02/2017   0:00       BROOKLYN    11214  40.593884 -73.990200
# 4        05/02/2017   0:00      MANHATTAN    10001  40.749100 -73.992010
# 11       05/02/2017   0:00            NaN      NaN  40.825935 -73.859130
# 13       05/02/2017   0:00         QUEENS    11432  40.705826 -73.793970
# 14       05/02/2017   0:10       BROOKLYN    11206  40.696354 -73.940710
# 17       05/02/2017   0:30         QUEENS    11102  40.769787 -73.918420
# 18       05/02/2017   0:35       BROOKLYN    11228  40.625240 -74.009470
# 19       05/02/2017   0:37            NaN      NaN  40.872310 -73.871956
# 21       05/02/2017   0:50      MANHATTAN    10016  40.744064 -73.987755
# 23       05/02/2017  10:00       BROOKLYN    11215  40.670520 -73.995120
# 26       05/02/2017  10:00       BROOKLYN    11218  40.643574 -73.971660
# 30       05/02/2017  10:10            NaN      NaN  40.798256 -73.924020
# 31       05/02/2017  10:15          BRONX    10471  40.908848 -73.901660
# 32       05/02/2017  10:15         QUEENS    11434  40.666840 -73.789410
# 33       05/02/2017  10:15            NaN      NaN  40.840824 -73.945970
# 34       05/02/2017  10:16      MANHATTAN    10013  40.715584 -74.003040
# 35       05/02/2017  10:17          BRONX    10473  40.820747 -73.867660
# 37       05/02/2017  10:20         QUEENS    11354  40.761547 -73.831130
# 40       05/02/2017  10:25            NaN      NaN  40.826855 -73.922676
# 41       05/02/2017  10:28          BRONX    10469  40.877907 -73.841870
# 43       05/02/2017  10:30         QUEENS    11354  40.764706 -73.811005
# 44       05/02/2017  10:30            NaN      NaN  40.668495 -73.925606
# 45       05/02/2017  10:30            NaN      NaN  40.788475 -73.967020
# 50       05/02/2017  10:39            NaN      NaN  40.601680 -74.163300
# 52       05/02/2017  10:40       BROOKLYN    11213  40.678880 -73.935610
# 53       05/02/2017  10:44       BROOKLYN    11208  40.674385 -73.878970
# 55       05/02/2017  10:45      MANHATTAN    10030  40.823647 -73.943855
# 58       05/02/2017  11:00          BRONX    10461  40.851090 -73.848220
# 19                                    NaN
# 21                               5 AVENUE
# 23                                    NaN
# 26                          EAST 8 STREET
# 30                                    NaN
# 31                                    NaN
# 32                   NORTH CONDUIT AVENUE
# 33                                    NaN
# 34                       LAFAYETTE STREET
# 35                           NOBLE AVENUE
# 37                            MAIN STREET
# 40                                    NaN
# 41                                    NaN
# 43                     NORTHERN BOULEVARD
# 44                                    NaN
# 45                                    NaN
# 50                             SIGNS ROAD
# 52                        HERKIMER STREET
# 53                          PITKIN AVENUE
# 55                        WEST 145 STREET
# 58                        SEMINOLE AVENUE
# 59                                    NaN
# ...                                   ...
# 1026287                               NaN
# 1026288  WEST FORDHAM ROAD
# 1026289  UNION STREET
# 1026290  FAIRVIEW AVENUE
# 1026292  FDR DRIVE
# 1026294  BAY 28 STREET
# 1026296  LEXINGTON AVENUE
# 1026299  KINGSTON AVENUE
# 1026300  EAST MOSHOLU PARKWAY NORTH
# 1026301  MARCUS GARVEY BOULEVARD
# 1026302  260 STREET
# 1026305  PROSPECT PLACE
# 1026306  CORONA AVENUE
# 1026307  ALBANY AVENUE
# 1026308                               NaN
# 1026310  UTICA AVENUE
# 1026314  QUEENS BOULEVARD
# 1026317  85 ROAD
# 1026318  104 AVENUE
# 1026319  BEMENT AVENUE
# 1026320  234 STREET
# 1026321  EARHART LANE
# 1026322  NEW UTRECHT AVENUE
# 1026323  126 STREET
# 1026326  MAPLE DRIVE
# 1026327  CATHERINE STREET
# 1026328  FARRINGTON STREET
# 1026333  85 AVENUE
# 1026334  EAST 68 STREET
# 1026335  GERARD AVENUE
#
#                                   OFF STREET NAME         ...          \
# 2                                             NaN         ...
# 3                                             NaN         ...
# 4                                             NaN         ...
# 11                                            NaN         ...
# 13                                            NaN         ...
# 14                                            NaN         ...
# 17       25-38     31 STREET                              ...
# 18                                            NaN         ...
# 19                                            NaN         ...
# 21                                            NaN         ...
# 23       155       2 AVENUE                               ...
# 26                                            NaN         ...
# 30                                            NaN         ...
# 31       6038      LIEBIG AVENUE                          ...
# 32                                            NaN         ...
# 33                                            NaN         ...
# 34                                            NaN         ...
# 35                                            NaN         ...
# 37                                            NaN         ...
# 40                                            NaN         ...
# 41       3402      WICKHAM AVENUE                         ...
# 43                                            NaN         ...
# 44                                            NaN         ...
# 45                                            NaN         ...
# 50                                            NaN         ...
# 52                                            NaN         ...
# 53                                            NaN         ...
# 55                                            NaN         ...
# 58                                            NaN         ...
# 59       1625      EAST 55 STREET                         ...
# ...                                           ...         ...
# 1026287                                       NaN         ...
# 1026288                                       NaN         ...
# 1026289                                       NaN         ...
# 1026290                                       NaN         ...
# 1026292                                       NaN         ...
# 1026294                                       NaN         ...
# 1026296                                       NaN         ...
# 1026299                                       NaN         ...
# 1026300                                       NaN         ...
# 1026301                                       NaN         ...
# 1026302                                       NaN         ...
# 1026305                                       NaN         ...
# 1026306                                       NaN         ...
# 1026307                                       NaN         ...
# 1026308                                       NaN         ...
# 1026310                                       NaN         ...
# 1026314                                       NaN         ...
# 1026317                                       NaN         ...
# 1026318                                       NaN         ...
# 1026319                                       NaN         ...
# 1026320                                       NaN         ...
# 1026321                                       NaN         ...
# 1026322                                       NaN         ...
# 1026323                                       NaN         ...
# 1026326                                       NaN         ...
# 1026327                                       NaN         ...
# 1026328                                       NaN         ...
# 1026333                                       NaN         ...
# 1026334                                       NaN         ...
# 1026335                                       NaN         ...
#
#           CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 2                           Unspecified                    Unspecified
# 3        Driver Inattention/Distraction                            NaN
# 4                           Unspecified                            NaN
# 11                          Unspecified                            NaN
# 13                          Unspecified                            NaN
# 14       Driver Inattention/Distraction                            NaN
# 17       Driver Inattention/Distraction                            NaN
# 18                          Unspecified                            NaN
# 19                                  NaN                            NaN
# 21                                  NaN                            NaN
# 23                          Unspecified                            NaN
# 26                          Unspecified                            NaN
# 30                          Unspecified                            NaN
# 31                          Unspecified                            NaN
# 32                          Unspecified                            NaN
# 33                          Unspecified                            NaN
# 34       Driver Inattention/Distraction                            NaN
# 35                          Unspecified                            NaN
# 37                   Turning Improperly                            NaN
# 40                    Oversized Vehicle                            NaN
# 41                                  NaN                            NaN
# 43                                  NaN                            NaN
# 44                          Unspecified                            NaN
# 45                                  NaN                            NaN
# 50                                  NaN                            NaN
# 52                          Unspecified                            NaN
# 53                                  NaN                            NaN
# 55                          Unspecified                            NaN
# 58                          Unspecified                            NaN
# 59                                  NaN                            NaN
# ...                                 ...                            ...
# 1026287                     Unspecified                            NaN
# 1026288                     Unspecified                            NaN
# 1026289                     Unspecified                            NaN
# 1026290                     Unspecified                            NaN
# 1026292                     Unspecified                            NaN
# 1026294                     Unspecified                            NaN
# 1026296                 Other Vehicular                            NaN
# 1026299                             NaN                            NaN
# 1026300                     Unspecified                            NaN
# 1026301                     Unspecified                    Unspecified
# 1026302                     Unspecified                            NaN
# 1026305                     Unspecified                            NaN
# 1026306                     Unspecified                            NaN
# 1026307                     Unspecified                            NaN
# 1026308                             NaN                            NaN
# 1026310                     Unspecified                            NaN
# 1026314                     Unspecified                            NaN
# 1026317                     Unspecified                            NaN
# 1026318                     Unspecified                            NaN
# 1026319                     Unspecified                            NaN
# 1026320                     Unspecified                            NaN
# 1026321                     Unspecified                            NaN
# 1026322                     Unspecified                            NaN
# 1026323                     Unspecified                    Unspecified
# 1026326                     Unspecified                            NaN
# 1026327             Driver Inexperience                            NaN
# 1026328                     Unspecified                            NaN
# 1026333                     Unspecified                            NaN
# 1026334                 Other Vehicular                            NaN
# 1026335                     Unspecified                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 11                                 NaN                            NaN
# 13                                 NaN                            NaN
# 14                                 NaN                            NaN
# 17                                 NaN                            NaN
# 18                                 NaN                            NaN
# 19                                 NaN                            NaN
# 21                                 NaN                            NaN
# 23                                 NaN                            NaN
# 26                                 NaN                            NaN
# 30                                 NaN                            NaN
# 31                                 NaN                            NaN
# 32                                 NaN                            NaN
# 33                                 NaN                            NaN
# 34                                 NaN                            NaN
# 35                                 NaN                            NaN
# 37                                 NaN                            NaN
# 1026292                  NaN                 NaN                 NaN
# 1026294                  NaN                 NaN                 NaN
# 1026296                  NaN                 NaN                 NaN
# 1026299                  NaN                 NaN                 NaN
# 1026300                  NaN                 NaN                 NaN
# 1026301    PASSENGER VEHICLE                 NaN                 NaN
# 1026302                  NaN                 NaN                 NaN
# 1026305                  NaN                 NaN                 NaN
# 1026306                  NaN                 NaN                 NaN
# 1026307                  NaN                 NaN                 NaN
# 1026308                  NaN                 NaN                 NaN
# 1026310                  NaN                 NaN                 NaN
# 1026314                  NaN                 NaN                 NaN
# 1026317                  NaN                 NaN                 NaN
# 1026318                  NaN                 NaN                 NaN
# 1026319                  NaN                 NaN                 NaN
# 1026320                  NaN                 NaN                 NaN
# 1026321                  NaN                 NaN                 NaN
# 1026322                  NaN                 NaN                 NaN
# 1026323    PASSENGER VEHICLE                 NaN                 NaN
# 1026326                  NaN                 NaN                 NaN
# 1026327                  NaN                 NaN                 NaN
# 1026328                  NaN                 NaN                 NaN
# 1026333                  NaN                 NaN                 NaN
# 1026334                  NaN                 NaN                 NaN
# 1026335                  NaN                 NaN                 NaN
#
# [467365 rows x 29 columns]

# %%
X = []
Y = []
for i in car['LONGITUDE']:
    X.append(i)
for i in car['LATITUDE']:
    Y.append(i)
    

import numpy 
points = numpy.zeros(shape=(len(Y),2))
for i in range(0,len(Y)):
    if Y[i] <41 and X[i]<0: 
        points[i][0] = X[i]
        points[i][1] = Y[i]
    else:
        points[i][0] = -74.251609
        points[i][1]= 40.499186

# %%
import numpy as np
import random
def cluster_points(X, mu):
    clusters  = {}
    for x in X:
        bestmukey = min([(i[0], np.linalg.norm(x-mu[i[0]])) \
                    for i in enumerate(mu)], key=lambda t:t[1])[0]
        try:
            clusters[bestmukey].append(x)
        except KeyError:
            clusters[bestmukey] = [x]
    return clusters
 
def reevaluate_centers(mu, clusters):
    newmu = []
    keys = sorted(clusters.keys())
    for k in keys:
        newmu.append(np.mean(clusters[k], axis = 0))
    return newmu
def has_converged(mu, oldmu):
    return (set([tuple(a) for a in mu]) == set([tuple(a) for a in oldmu]))

def find_centers(X, K):
    # Initialize to K random centers
    oldmu = random.sample(X, K)
    mu = random.sample(X, K)
    while not has_converged(mu, oldmu):
        oldmu = mu
        # Assign all points in X to clusters
        clusters = cluster_points(X, mu)
        # Reevaluate centers
        mu = reevaluate_centers(oldmu, clusters)
    return(mu, clusters)

# %%
ck2 = find_centers(points,2)
ck3 = find_centers(points,3)
ck4 = find_centers(points,4)
ck5 = find_centers(points,5)
ck6 = find_centers(points,6)

# %%
f =  open('ck2.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1


# all the points besides the clusters   
for i in range(0, len(ck2)):
    for j in ck2[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
#the clusters points
for i in ck2[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-db47fa327c2c> in <module>()
#       5
#       6 # all the points besides the clusters
# ----> 7 for i in range(0, len(ck2)):
#       8     for j in ck2[1][i]:
#       9         s= ""
#
# NameError: name 'ck2' is not defined

# %%
f =  open('ck3.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1


    
for i in range(0, len(ck3)):
    for j in ck3[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
for i in ck3[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1   
f.close()

# %%
k = ck4

f =  open('ck4.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()

# %%
k = ck5

f =  open('ck5.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()

# %%
k = ck6

f =  open('ck6.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()

# %%
bike =  df.loc[df['VEHICLE TYPE CODE 1'] == "BICYCLE"]
bike.dropna(subset=['LATITUDE'], inplace=True)
bike.dropna(subset=['LONGITUDE'], inplace=True)
bike
# Out:
# /Users/Enchanter/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/Enchanter/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                DATE   TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 78       05/02/2017  11:15   BROOKLYN    11201  40.701267 -73.980736
# 116      05/02/2017  12:25        NaN      NaN  40.681004 -73.994350
# 266      05/02/2017  15:37  MANHATTAN    10280  40.710080 -74.016390
# 340      05/02/2017  17:00   BROOKLYN    11208  40.672390 -73.874630
# 341      05/02/2017  17:00  MANHATTAN    10022  40.760098 -73.976060
# 450      05/02/2017  20:10     QUEENS    11377  40.745110 -73.908640
# 463      05/02/2017  21:04   BROOKLYN    11236  40.633800 -73.889700
# 607      05/02/2017   8:45   BROOKLYN    11226  40.655594 -73.947170
# 781      05/01/2017  13:05   BROOKLYN    11234  40.619070 -73.934320
# 782      05/01/2017  13:05  MANHATTAN    10128  40.779495 -73.953500
# 817      05/01/2017  14:15      BRONX    10460  40.836130 -73.889870
# 450                                           NaN         ...
# 463                                           NaN         ...
# 607                                           NaN         ...
# 781                                           NaN         ...
# 782                                           NaN         ...
# 817                                           NaN         ...
# 890                                           NaN         ...
# 894                                           NaN         ...
# 1000                                          NaN         ...
# 1021                                          NaN         ...
# 1056     173       HIMROD STREET                          ...
# 1074                                          NaN         ...
# 1269                                          NaN         ...
# 1334                                          NaN         ...
# 1374     17        EAST 13 STREET                         ...
# 1390                                          NaN         ...
# 1450                                          NaN         ...
# 1532                                          NaN         ...
# 1562     822       10 AVENUE                              ...
# 1643                                          NaN         ...
# 1651                                          NaN         ...
# 1759                                          NaN         ...
# 1779     85        EAST DRIVE                             ...
# 1792     1554      FULTON STREET                          ...
# 1859     4716      AVENUE H                               ...
# ...                                           ...         ...
# 986326                                        NaN         ...
# 986703                                        NaN         ...
# 987242                                        NaN         ...
# 988393                                        NaN         ...
# 989414                                        NaN         ...
# 989861                                        NaN         ...
# 990345                                        NaN         ...
# 990715                                        NaN         ...
# 991033                                        NaN         ...
# 992513                                        NaN         ...
# 992956                                        NaN         ...
# 994938                                        NaN         ...
# 996656                                        NaN         ...
# 998024                                        NaN         ...
# 999570                                        NaN         ...
# 1000738                                       NaN         ...
# 1001240                                       NaN         ...
# 1003282                                       NaN         ...
# 1003411                                       NaN         ...
# 1003452                                       NaN         ...
# 1004517                                       NaN         ...
# 1007782                                       NaN         ...
# 1008304                                       NaN         ...
# 1008363                                       NaN         ...
# 1010376                                       NaN         ...
# 1011230                                       NaN         ...
# 1015444                                       NaN         ...
# 1019130                                       NaN         ...
# 1019942                                       NaN         ...
# 1020326                                       NaN         ...
#
#                              CONTRIBUTING FACTOR VEHICLE 2  \
# 78                                             Unspecified
# 116                          Failure to Yield Right-of-Way
# 266      Pedestrian/Bicyclist/Other Pedestrian Error/Co...
# 340                                            Unspecified
# 341                                            Unspecified
# 450                         Driver Inattention/Distraction
# 463                          Failure to Yield Right-of-Way
# 607                                                    NaN
# 781                                            Unspecified
# 782                                            Unspecified
# 817                         Driver Inattention/Distraction
# 890                                            Unspecified
# 894                                            Unspecified
# 1000                                           Unspecified
# 1021                                           Unspecified
# 1056                                           Unspecified
# 1074                                           Unspecified
# 1269                                                   NaN
# 1334                                           Unspecified
# 1374                        Driver Inattention/Distraction
# 1390                                                   NaN
# 1450                                           Unspecified
# 1532                                           Unspecified
# 1562                        Passing or Lane Usage Improper
# 1643                                           Unspecified
# 1651                                      Backing Unsafely
# 1759                                 Following Too Closely
# 1779                                                   NaN
# 1792                                           Unspecified
# 1859                                           Unspecified
# ...                                                    ...
# 986326                                         Unspecified
# 986703                                         Unspecified
# 987242                                         Unspecified
# 988393                                         Unspecified
# 989414                                         Unspecified
# 989861                                         Unspecified
# 990345                                         Unspecified
# 990715                                         Unspecified
# 991033                                         Unspecified
# 992513                                         Unspecified
# 992956                                         Unspecified
# 994938                                                 NaN
# 996656                                         Unspecified
# 998024                                         Unspecified
# 999570                                                 NaN
# 1000738                                        Unspecified
# 1759                 PASSENGER VEHICLE                  NaN
# 1779                               NaN                  NaN
# 1792                 PASSENGER VEHICLE                  NaN
# 1859                               NaN                  NaN
# ...                                ...                  ...
# 986326               PASSENGER VEHICLE                  NaN
# 986703   SPORT UTILITY / STATION WAGON                  NaN
# 987242                         UNKNOWN                  NaN
# 988393                         UNKNOWN                  NaN
# 989414               PASSENGER VEHICLE                  NaN
# 989861                         UNKNOWN                  NaN
# 990345   SPORT UTILITY / STATION WAGON                  NaN
# 990715                         UNKNOWN                  NaN
# 991033               PASSENGER VEHICLE                  NaN
# 992513                         UNKNOWN                  NaN
# 992956               PASSENGER VEHICLE                  NaN
# 994938                             NaN                  NaN
# 996656                         UNKNOWN                  NaN
# 998024                         UNKNOWN                  NaN
# 999570                             NaN                  NaN
# 1000738                        UNKNOWN                  NaN
# 1001240  SPORT UTILITY / STATION WAGON                  NaN
# 1003282              PASSENGER VEHICLE                  NaN
# 1003411                        UNKNOWN                  NaN
# 1003452                        UNKNOWN                  NaN
# 1004517              PASSENGER VEHICLE                  NaN
# 1007782              PASSENGER VEHICLE                  NaN
# 1008304  SPORT UTILITY / STATION WAGON                  NaN
# 1008363              PASSENGER VEHICLE                  NaN
# 1010376                            BUS                  NaN
# 1011230              PASSENGER VEHICLE                  NaN
# 1015444                          OTHER                  NaN
# 1019130                        UNKNOWN                  NaN
# 1019942                            NaN                  NaN
# 1020326              PASSENGER VEHICLE                  NaN
#
#         VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 78                      NaN                 NaN
# 116                     NaN                 NaN
# 266                     NaN                 NaN
# 340                     NaN                 NaN
# 341                     NaN                 NaN
# 450                     NaN                 NaN
# 463                     NaN                 NaN
# 607                     NaN                 NaN
# 781                     NaN                 NaN
# 782                     NaN                 NaN
# 817                     NaN                 NaN
# 890                     NaN                 NaN
# 894                     NaN                 NaN
# 1000                    NaN                 NaN
# 1021                    NaN                 NaN
# 1056                    NaN                 NaN
# 1074                    NaN                 NaN
# 1269                    NaN                 NaN
# 1334                    NaN                 NaN
# 1374                    NaN                 NaN
# 1390                    NaN                 NaN
# 1450                    NaN                 NaN
# 1532                    NaN                 NaN
# 1562                    NaN                 NaN
# 1643                    NaN                 NaN
# 1651                    NaN                 NaN
# 1759                    NaN                 NaN
# 1779                    NaN                 NaN
# 1792                    NaN                 NaN
# 1859                    NaN                 NaN
# ...                     ...                 ...
# 986326                  NaN                 NaN
# 986703                  NaN                 NaN
# 987242                  NaN                 NaN
# 988393                  NaN                 NaN
# 989414                  NaN                 NaN
# 989861                  NaN                 NaN
# 990345                  NaN                 NaN
# 990715                  NaN                 NaN
# 991033                  NaN                 NaN
# 992513                  NaN                 NaN
# 992956                  NaN                 NaN
# 994938                  NaN                 NaN
# 996656                  NaN                 NaN
# 998024                  NaN                 NaN
# 999570                  NaN                 NaN
# 1000738                 NaN                 NaN
# 1001240                 NaN                 NaN
# 1003282                 NaN                 NaN
# 1003411                 NaN                 NaN
# 1003452                 NaN                 NaN
# 1004517                 NaN                 NaN
# 1007782                 NaN                 NaN
# 1008304                 NaN                 NaN
# 1008363                 NaN                 NaN
# 1010376                 NaN                 NaN
# 1011230                 NaN                 NaN
# 1015444                 NaN                 NaN
# 1019130                 NaN                 NaN
# 1019942                 NaN                 NaN
# 1020326                 NaN                 NaN
#
# [1847 rows x 29 columns]

# %%
X = []
Y = []
for i in car['LONGITUDE']:
    X.append(i)
for i in car['LATITUDE']:
    Y.append(i)
    

import numpy 
points = numpy.zeros(shape=(len(Y),2))
for i in range(0,len(Y)):
    if Y[i] <41 and X[i]<0: 
        points[i][0] = X[i]
        points[i][1] = Y[i]
    else:
        points[i][0] = -74.251609
        points[i][1]= 40.499186

# %%
bk2 = find_centers(points,2)
bk3 = find_centers(points,3)
bk4 = find_centers(points,4)
bk5 = find_centers(points,5)
bk6 = find_centers(points,6)

# %%
f =  open('bk2.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1


# all the points besides the clusters   
for i in range(0, len(bk2)):
    for j in bk2[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
#the clusters points
for i in bk2[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 
f.close()

# %%
f =  open('bk3.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1


    
for i in range(0, len(bk3)):
    for j in bk3[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
for i in bk3[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1   
f.close()

# %%
k = bk4

f =  open('bk4.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()

# %%
k = bk5

f =  open('bk5.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()

# %%
k = bk6

f =  open('bk6.csv', 'w')
f.write("lat,lon,type,\n")
counter = 1
for i in k[0]:
    s= ""
    s = s + str(i[0]) +  ','+  str(i[1]) + "," + str(counter*10) + '\n'
    f.write(s )
    counter=  counter +1 

    
for i in range(0, len(k[1])):
    for j in k[1][i]:
        s= ""
        s = s + str(j[0]) +  ','+  str(j[1]) + "," + str(i+1) + '\n'
        f.write(s)
    
f.close()
